# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de los puntos de interpolación (datos del problema)
x_points = np.array([0.5, 1.0, 1.5, 2.0])  # Posición en metros
y_points = np.array([1.2, 2.3, 3.7, 5.2])   # Deformación en mm

# Función de interpolación de Lagrange (sin cambios)
def lagrange_interpolation(x, x_points, y_points):
    n = len(x_points)
    result = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# a) Determinar la deformación en x = 1.25 m
x_eval = 1.25
y_eval = lagrange_interpolation(x_eval, x_points, y_points)
print(f"a) La deformación esperada en x = {x_eval} m es: {y_eval:.2f} mm")

# b) Graficar la interpolación en el rango [0.5, 2.0]
x_values = np.linspace(min(x_points), max(x_points), 100)
y_values = [lagrange_interpolation(x, x_points, y_points) for x in x_values]

plt.figure(figsize=(8,5))
plt.plot(x_values, y_values, label="Interpolación de Lagrange", color="blue")
plt.scatter(x_points, y_points, color="red", label="Datos experimentales")
plt.scatter([x_eval], [y_eval], color="green", label=f"Punto interpolado (x={x_eval}m)")
plt.xlabel("Posición en la viga (m)")
plt.ylabel("Deformación (mm)")
plt.title("Deformación de la viga - Interpolación de Lagrange")
plt.legend()
plt.grid(True)
plt.savefig("deformacion_viga.png")
plt.show()
# Out:
# a) La deformación esperada en x = 1.25 m es: 2.98 mm

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de los puntos de interpolación (datos del problema)
x_points = np.array([1.0, 2.5, 4.0, 5.5])  # Profundidad en cm
y_points = np.array([85, 78, 69, 60])      # Temperatura en °C

# Función de interpolación de Lagrange (la misma del código original)
def lagrange_interpolation(x, x_points, y_points):
    n = len(x_points)
    result = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# a) Determinar la temperatura a 3.0 cm de profundidad
x_eval = 3.0
y_eval = lagrange_interpolation(x_eval, x_points, y_points)
print(f"a) La temperatura estimada a {x_eval} cm de profundidad es: {y_eval:.2f} °C")

# b) Graficar la interpolación en el rango [1.0, 5.5]
x_values = np.linspace(min(x_points), max(x_points), 100)
y_values = [lagrange_interpolation(x, x_points, y_points) for x in x_values]

plt.figure(figsize=(8,5))
plt.plot(x_values, y_values, label="Interpolación de Lagrange", color="blue")
plt.scatter(x_points, y_points, color="red", label="Datos registrados")
plt.scatter([x_eval], [y_eval], color="green", label=f"Punto interpolado (x={x_eval}cm)")
plt.xlabel("Profundidad (cm)")
plt.ylabel("Temperatura (°C)")
plt.title("Temperatura del motor - Interpolación de Lagrange")
plt.legend()
plt.grid(True)
plt.savefig("temperatura_motor.png")
plt.show()
# Out:
# a) La temperatura estimada a 3.0 cm de profundidad es: 75.12 °C

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de los puntos de interpolación (datos del problema)
x_points = np.array([2.0, 4.0, 6.0, 8.0])  # Altitud en km
y_points = np.array([2500, 2300, 2150, 2050])  # Consumo en kg/h

# Función de interpolación de Lagrange (sin cambios)
def lagrange_interpolation(x, x_points, y_points):
    n = len(x_points)
    result = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# a) Determinar el consumo a 5 km de altitud
x_eval = 5.0
y_eval = lagrange_interpolation(x_eval, x_points, y_points)
print(f"a) El consumo estimado a {x_eval} km de altitud es: {y_eval:.2f} kg/h")

# b) Graficar la interpolación en el rango [2.0, 8.0]
x_values = np.linspace(min(x_points), max(x_points), 100)
y_values = [lagrange_interpolation(x, x_points, y_points) for x in x_values]

plt.figure(figsize=(8,5))
plt.plot(x_values, y_values, label="Interpolación de Lagrange", color="blue")
plt.scatter(x_points, y_points, color="red", label="Datos medidos")
plt.scatter([x_eval], [y_eval], color="green", label=f"Punto interpolado (x={x_eval}km)")
plt.xlabel("Altitud (km)")
plt.ylabel("Consumo de combustible (kg/h)")
plt.title("Consumo de combustible en aeronaves - Interpolación de Lagrange")
plt.legend()
plt.grid(True)
plt.savefig("consumo_combustible.png")
plt.show()
# Out:
# a) El consumo estimado a 5.0 km de altitud es: 2218.75 kg/h
